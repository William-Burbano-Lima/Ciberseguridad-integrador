# %% [markdown]
# <a href="https://colab.research.google.com/github/William-Burbano-Lima/Ciberseguridad-integrador/blob/main/1_DIA_ACTIVOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TALENTO TECH - CIBERSEGURIDAD
#
# NIVEL INTEGRADOR
# ___
# TALLER 2 SGSI
#
# # Plantilla de Identificación y Clasificación de Activos de Información
#
# ## 1. INFORMACIÓN GENERAL DEL ACTIVO
#
# ### 1.1 Datos Básicos
# | Campo | Descripción | Ejemplo |
# |-------|-------------|---------|
# | ID del Activo | [Código único identificador] | ACT-001 |
# | Nombre del Activo | [Nombre descriptivo] | Base de datos de clientes |
# | Descripción | [Descripción detallada] | Sistema que almacena información de clientes activos |
# | Tipo de Activo | [Categoría del activo] | Información/Software/Hardware/Servicio |
# | Ubicación | [Ubicación física/lógica] | Servidor principal - Rack 3 |
# | Propietario | [Responsable del activo] | Departamento de Ventas |
# | Custodio | [Responsable técnico] | Administrador de Base de Datos |
#
# ### 1.2 Estado del Activo
# - [ ] Activo
# - [ ] En desarrollo
# - [ ] En mantenimiento
# - [ ] Obsoleto
# - [ ] Dado de baja
#
# ## 2. VALORACIÓN DE SEGURIDAD
#
# ### 2.1 Clasificación de Confidencialidad
# - [ ] Pública
# - [ ] Interna
# - [ ] Confidencial
# - [ ] Estrictamente Confidencial
#
# *Justificación:* [Explicar razones de la clasificación]
#
# ### 2.2 Valoración de Propiedades
# Escala: 1 (Bajo) a 5 (Crítico)
#
# | Propiedad | Valor | Justificación |
# |-----------|-------|---------------|
# | Confidencialidad | [1-5] | [Explicación] |
# | Integridad | [1-5] | [Explicación] |
# | Disponibilidad | [1-5] | [Explicación] |
#
# ### 2.3 Criticidad Total
# - [ ] Crítico (13-15)
# - [ ] Alto (10-12)
# - [ ] Medio (7-9)
# - [ ] Bajo (3-6)
#
# ## 3. DEPENDENCIAS Y RELACIONES
#
# ### 3.1 Activos Relacionados
# | ID Activo | Nombre | Tipo de Relación |
# |-----------|---------|------------------|
# | [ID] | [Nombre] | [Depende de/Soporta a] |
#
# ### 3.2 Usuarios y Accesos
# | Rol/Grupo | Tipo de Acceso | Justificación |
# |-----------|----------------|---------------|
# | [Rol] | [Lectura/Escritura/Admin] | [Razón] |
#
# ## 4. CONTROLES DE SEGURIDAD
#
# ### 4.1 Controles Actuales
# | Tipo de Control | Descripción | Estado |
# |----------------|-------------|---------|
# | [Preventivo/Detectivo/Correctivo] | [Descripción] | [Implementado/Pendiente] |
#
# ### 4.2 Requisitos de Protección
# - [ ] Backup
# - [ ] Cifrado
# - [ ] Control de Acceso
# - [ ] Monitorización
# - [ ] Otros: _____________
#
# ## 5. CICLO DE VIDA
#
# ### 5.1 Información Temporal
# | Campo | Valor |
# |-------|-------|
# | Fecha de Registro | [DD/MM/AAAA] |
# | Fecha Última Revisión | [DD/MM/AAAA] |
# | Próxima Revisión | [DD/MM/AAAA] |
#
# ### 5.2 Requisitos de Retención
# - Periodo de retención: [Especificar]
# - Método de eliminación: [Especificar]
# - Requisitos legales: [Especificar]
#
# ## 6. ANÁLISIS DE RIESGOS
#
# ### 6.1 Amenazas Identificadas
# | Amenaza | Probabilidad | Impacto | Nivel de Riesgo |
# |---------|-------------|---------|-----------------|
# | [Descripción] | [Alta/Media/Baja] | [Alto/Medio/Bajo] | [Crítico/Alto/Medio/Bajo] |
#
# ### 6.2 Vulnerabilidades Conocidas
# | Vulnerabilidad | Estado | Plan de Mitigación |
# |----------------|--------|-------------------|
# | [Descripción] | [Abierta/En proceso/Cerrada] | [Acciones] |
#
# ## 7. DOCUMENTACIÓN RELACIONADA
#
# ### 7.1 Referencias
# - Políticas aplicables: [Listar]
# - Procedimientos: [Listar]
# - Manuales: [Listar]
#
# ### 7.2 Historial de Cambios
# | Fecha | Responsable | Descripción del Cambio |
# |-------|-------------|------------------------|
# | [Fecha] | [Nombre] | [Descripción] |
#
# ## 8. APROBACIONES
#
# ### 8.1 Validación
# | Rol | Nombre | Firma | Fecha |
# |-----|---------|-------|-------|
# | Propietario | | | |
# | Custodio | | | |
# | Oficial de Seguridad | | | |
#
# ### 8.2 Observaciones
# [Espacio para comentarios adicionales o notas importantes]
