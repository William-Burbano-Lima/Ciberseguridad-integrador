# %% [markdown]
# <a href="https://colab.research.google.com/github/William-Burbano-Lima/Ciberseguridad-integrador/blob/main/Lab01_phishing_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio práctico para realizar una simulación de phishing en un entorno controlado utilizando **Social Engineering Toolkit (SET)** en **Kali Linux**.
#
# > **⚠ ADVERTENCIA**: Este ejercicio debe realizarse **únicamente** en entornos controlados, como laboratorios de ciberseguridad o redes de prueba. **No debe usarse para actividades ilegales ni sin consentimiento**.
#
# ---
#
# ## **Objetivo**
# Simular un ataque de phishing con **SET** en **Kali Linux**, clonando una página web legítima y capturando credenciales en un entorno seguro.
#
# ## **Requisitos**
# - Kali Linux instalado (o una máquina virtual con Kali)
# - Social Engineering Toolkit (ya viene en Kali Linux)
# - Acceso a una red de pruebas
#
# ---
#
# ## **Pasos del Ejercicio**
#
# ### **1️⃣ Abrir Social Engineering Toolkit (SET)**
# Ejecuta el siguiente comando en la terminal de Kali Linux:
#
# ```bash
# sudo setoolkit
# ```
#
# Aparecerá el menú de SET.
#
# ---
#
# ### **2️⃣ Seleccionar el ataque de ingeniería social**
# En el menú principal, elige la opción:
#
# ```
# 1) Social-Engineering Attacks
# ```
#
# Presiona **Enter**.
#
# ---
#
# ### **3️⃣ Elegir el ataque de phishing**
# Selecciona la opción:
#
# ```
# 2) Website Attack Vectors
# ```
#
# Presiona **Enter**.
#
# ---
#
# ### **4️⃣ Clonar una página web**
# Elige la opción:
#
# ```
# 3) Credential Harvester Attack Method
# ```
#
# Presiona **Enter**.
#
# ---
#
# ### **5️⃣ Configurar el ataque**
# SET te pedirá que elijas la técnica de ataque. Selecciona:
#
# ```
# 2) Site Cloner
# ```
#
# Presiona **Enter**.
#
# Luego, te pedirá la **IP local** donde se alojará la página falsa. Para encontrar tu IP local, usa:
#
# ```bash
# ip a | grep inet
# ```
#
# Introduce la dirección IP local de Kali Linux y presiona **Enter**.
#
# ---
#
# ### **6️⃣ Introducir la URL de la página a clonar**
# Por ejemplo, si deseas clonar la página de inicio de sesión de Gmail (solo en entornos de prueba):
#
# ```
# https://accounts.google.com
# ```
#
# Presiona **Enter**.
#
# SET descargará la página e insertará un script para capturar credenciales.
#
# ---
#
# ### **7️⃣ Iniciar el servidor falso**
# SET configurará el servidor y mostrará:
#
# ```
# [*] Credential harvester is running on port 80...
# ```
#
# Esto significa que la página falsa está lista para recibir visitas.
#
# ---
#
# ### **8️⃣ Capturar credenciales**
# Cuando alguien ingrese sus datos en la página clonada, SET mostrará las credenciales en la terminal, como:
#
# ```
# [+] New credentials captured:
# Username: victima@gmail.com
# Password: password123
# ```
#
# ---
#
# ## **Conclusión**
# Este ejercicio demuestra cómo los atacantes pueden usar **ingeniería social** para obtener credenciales mediante **phishing**. Es fundamental entrenar a usuarios y empleados para detectar estos ataques y protegerse de ellos.
#
# ---
#
# ## **¿Cómo defenderse del phishing?**
# - **Verificar URLs** antes de ingresar credenciales.
# - **No hacer clic en enlaces sospechosos** en correos electrónicos.
# - **Usar autenticación de dos factores (2FA)**.
# - **Implementar herramientas de monitoreo** en redes empresariales.
# - **Educar a usuarios y empleados** sobre ciberseguridad.
#
# ---
# Talento Tech. 🚀
