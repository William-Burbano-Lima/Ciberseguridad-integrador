# %% [markdown]
# <a href="https://colab.research.google.com/github/William-Burbano-Lima/Ciberseguridad-integrador/blob/main/cifrado_descifrado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Talento Tech - Ciberseguridad
#
# Ejecutor Técnico: William Burbano Lima
# _![image.png](data:image/png;base64,...)__
# **TECNICAS BASICAS DE CIFRADO Y DESCIFRADO**
#
# ### 1. **Concepto de Cifrado César**
#
# El **Cifrado César** es un método de cifrado por sustitución en el que cada letra del texto es reemplazada por otra letra que se encuentra un número fijo de posiciones adelante en el alfabeto. Por ejemplo, si la clave es 3, la 'A' se convierte en 'D', la 'B' en 'E', y así sucesivamente.
#
# ### 2. **Función `ord` y `chr`**
#
# - **`ord(caracter)`**: Convierte un carácter en su valor ASCII.
#   - Ejemplo: `ord('A')` devuelve `65`.
#
# - **`chr(codigo)`**: Convierte un valor ASCII en su carácter correspondiente.
#   - Ejemplo: `chr(65)` devuelve `'A'`.
#
# ### 3. **Cálculo del Cifrado**
#
# Supongamos que queremos cifrar el mensaje **"Hola"** con una clave de **3**.
#
# - 'H' -> 'K' (`ord('H') + 3 = 72 + 3 = 75`, `chr(75) = 'K'`)
# - 'o' -> 'r' (`ord('o') + 3 = 111 + 3 = 114`, `chr(114) = 'r'`)
# - 'l' -> 'o' (`ord('l') + 3 = 108 + 3 = 111`, `chr(111) = 'o'`)
# - 'a' -> 'd' (`ord('a') + 3 = 97 + 3 = 100`, `chr(100) = 'd'`)
#
# Mensaje cifrado: **"Krod"**
#
# ### 4. **Cálculo del Descifrado**
#
# Para descifrar **"Krod"** con la clave **3**, restamos en lugar de sumar:
#
# - 'K' -> 'H' (`ord('K') - 3 = 75 - 3 = 72`, `chr(72) = 'H'`)
# - 'r' -> 'o' (`ord('r') - 3 = 114 - 3 = 111`, `chr(111) = 'o'`)
# - 'o' -> 'l' (`ord('o') - 3 = 111 - 3 = 108`, `chr(108) = 'l'`)
# - 'd' -> 'a' (`ord('d') - 3 = 100 - 3 = 97`, `chr(97) = 'a'`)
#
# Mensaje descifrado: **"Hola"**
#
# ### 5. **Ejemplos Adicionales**
#
# #### Cifrar el Mensaje "Python" con Clave 5
# - 'P' -> 'U'
# - 'y' -> 'd'
# - 't' -> 'y'
# - 'h' -> 'm'
# - 'o' -> 't'
# - 'n' -> 's'
#
# Mensaje cifrado: **"Udymts"**
#
# #### Descifrar el Mensaje "Udymts" con Clave 5
# - 'U' -> 'P'
# - 'd' -> 'y'
# - 'y' -> 't'
# - 'm' -> 'h'
# - 't' -> 'o'
# - 's' -> 'n'
#
# Mensaje descifrado: **"Python"**
#
# ### 6. **Manejo de Caracteres No Alfabéticos**
#
# En los programas, cualquier carácter que no sea una letra (como números, espacios o símbolos) se copia tal cual al mensaje cifrado o descifrado. Esto se maneja con la línea:
#
# ```python
# else:
#     mensaje_cifrado += caracter
# ```
#
# Esto asegura que el cifrado no altere la estructura general del texto más allá de las letras.
#
# ### 7. **Prueba de los Programas**
#
# Probar los programas cifrar.py y descifrar.py ingresando diferentes mensajes y claves para ver cómo funcionan en distintos casos. Por ejemplo:
#
# - **Mensaje:** "¡Hola Mundo!"
# - **Clave:** 4
# - **Cifrado:** "¡Lspi Qyrhs!"
# - **Descifrado con la misma clave:** "¡Hola Mundo!"
#
# ___
#
# **PRACTICA DE CLASE**
#
# Desarrollar los siguientes ejercicios aplicando los conceptos y scripts propuestos.
#
# ### **Ejercicio 1: Cifrado Básico**
#
# - **Mensaje:** "Seguridad en la información"
# - **Clave:** 7
# - **Instrucciones:**
#   1. Utiliza el programa de cifrado para cifrar este mensaje.
#   2. Observa el mensaje cifrado y anota el resultado.
#
# ### **Ejercicio 2: Descifrado Básico**
#
# - **Mensaje Cifrado:** "Zlhynsljv wv qh pualyzvtlyl"
# - **Clave:** 7
# - **Instrucciones:**
#   1. Utiliza el programa de descifrado para descifrar este mensaje.
#   2. Verifica si el mensaje descifrado tiene sentido.
#
# ### **Ejercicio 3: Mensaje con Caracteres Especiales**
#
# - **Mensaje:** "Hola, ¿cómo estás? ¡Todo bien!"
# - **Clave:** 3
# - **Instrucciones:**
#   1. Cifra este mensaje usando la clave 3.
#   2. Descifra el resultado para verificar si el programa maneja correctamente los signos de puntuación y caracteres especiales.
#
# ### **Ejercicio 4: Diferentes Claves**
#
# - **Mensaje:** "Python es genial"
# - **Instrucciones:**
#   1. Cifra el mensaje con las siguientes claves: 1, 5, 10, 15.
#   2. Descifra cada uno de los mensajes cifrados usando las mismas claves.
#   3. Observa cómo cambian los mensajes según la clave utilizada.
#
# ### **Ejercicio 5: Cifrado con Clave Negativa**
#
# - **Mensaje:** "Seguridad"
# - **Clave:** -3
# - **Instrucciones:**
#   1. Usa el programa de cifrado para cifrar el mensaje usando una clave negativa.
#   2. Descifra el mensaje usando la misma clave negativa.
#   3. Analiza cómo el programa maneja las claves negativas.
#
# ### **Ejercicio 6: Detectar Errores**
#
# - **Mensaje Cifrado:** "Tqxxa iadxp"
# - **Instrucciones:**
#   1. Descifra el mensaje suponiendo que la clave correcta es desconocida.
#   2. Prueba diferentes claves hasta encontrar el mensaje original.
#   3. Anota cuántas claves diferentes tuviste que probar.
#
# ### **Ejercicio 7: Cifrar y Descifrar un Texto Largo**
#
# - **Mensaje:** "El cifrado César es uno de los métodos más antiguos y simples de cifrado de texto."
# - **Clave:** 8
# - **Instrucciones:**
#   1. Cifra el mensaje completo.
#   2. Descifra el mensaje para asegurarte de que puedes recuperar el texto original.
#   3. Analiza la efectividad del cifrado para proteger textos largos.
#
# ### **Ejercicio 8: Crear tu Propio Mensaje**
#
# - **Instrucciones:**
#   1. Escribe un mensaje secreto de al menos 20 caracteres.
#   2. Cifra el mensaje con una clave de tu elección.
#   3. Pide a otra persona que descifre tu mensaje utilizando el programa de descifrado.
#
# ___
# Entrega para enviar en notebook
#
# **William Burbano Lima**
